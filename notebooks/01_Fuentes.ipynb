# %% [markdown]
# ### SETAS

# %%
import pandas as pd

# %%
data_87 = pd.read_csv('..\\data\\1987_data.csv', sep=',')
data_class = pd.read_csv('..\\data\\primary_data_edited.csv', sep=';')

# %%
data_87.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
data_87.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
data_87.nunique(axis=0).sum()
# Out:
# 119

# %%
data_87['class'].value_counts(normalize=True)
# Out:
# class
# e    0.517971
# p    0.482029
# Name: proportion, dtype: float64

# %%
data_87.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
data_class.head()
# Out:
#            family               name class cap-diameter cap-shape cap-surface  \
# 0  Amanita Family         Fly Agaric     p     [10, 20]    [x, f]      [g, h]
# 1  Amanita Family        Panther Cap     p      [5, 10]    [p, x]         [g]
# 2  Amanita Family  False Panther Cap     p     [10, 15]    [x, f]         NaN
# 3  Amanita Family        The Blusher     e      [5, 15]    [x, f]         NaN
# 4  Amanita Family          Death Cap     p      [5, 12]    [x, f]         [h]
#
#   cap-color does-bruise-or-bleed gill-attachment gill-spacing  ... stem-root  \
# 0    [e, o]                  [f]             [e]          NaN  ...       [s]
# 1       [n]                  [f]             [e]          NaN  ...       NaN
# 2    [g, n]                  [f]             [e]          NaN  ...       NaN
# 3       [n]                  [t]             NaN          NaN  ...       [b]
# 4       [r]                  [f]             NaN          [c]  ...       NaN
#
# ...

# %%
data_class['class'].value_counts(normalize=True)
# Out:
# class
# p    0.554913
# e    0.445087
# Name: proportion, dtype: float64

# %%
data_class.describe()
# Out:
#                    family        name class cap-diameter cap-shape  \
# count                 173         173   173          173       173
# unique                 23         173     2           51        27
# top     Tricholoma Family  Fly Agaric     p       [2, 5]       [x]
# freq                   43           1    96           16        48
#
#        cap-surface cap-color does-bruise-or-bleed gill-attachment  \
# count          133       173                  173             145
# unique          40        67                    2               8
# top            [y]       [n]                  [f]             [a]
# freq            14        38                  143              32
#
#        gill-spacing  ... stem-root stem-surface stem-color veil-type  \
# count           102  ...        27           65        173         9
# unique            3  ...         5           14         41         1
# top             [c]  ...       [s]          [s]        [w]       [u]
# ...

# %%
data_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   family                173 non-null    object
#  1   name                  173 non-null    object
#  2   class                 173 non-null    object
#  3   cap-diameter          173 non-null    object
#  4   cap-shape             173 non-null    object
#  5   cap-surface           133 non-null    object
#  6   cap-color             173 non-null    object
#  7   does-bruise-or-bleed  173 non-null    object
#  8   gill-attachment       145 non-null    object
#  9   gill-spacing          102 non-null    object
#  10  gill-color            173 non-null    object
#  11  stem-height           173 non-null    object
#  12  stem-width            173 non-null    object
#  13  stem-root             27 non-null     object
#  14  stem-surface          65 non-null     object
# ...

# %%
images = pd.read_csv('..\\data\\images\\_classes.csv')

# %%
images.head()
# Out:
#                                             filename  \
# 0  IMG_20230131_10221_Burst10_jpg.rf.3d0d859972a6...
# 1  IMG_20230131_105942_Burst18_jpg.rf.3cd9527b1bb...
# 2  IMG_20230205_210944_Burst11_jpg.rf.3d4a5083517...
# 3  IMG_20230206_114826_Burst18_jpg.rf.3cf73ef01b0...
# 4  IMG_20230207_120343_Burst20_jpg.rf.3cdd35e4008...
#
#     Amanita Vaginata Var - Vaginata   Amanita brunneitoxicaria  \
# 0                                 0                          0
# 1                                 0                          0
# 2                                 0                          1
# 3                                 0                          0
# 4                                 0                          0
#
#     Amanita phalloides-   Amanita princeps Corner - Bas  \
# 0                     0                               0
# 1                     0                               0
# 2                     0                               0
# ...

# %%
images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6693 entries, 0 to 6692
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   filename                          6693 non-null   object
#  1    Amanita Vaginata Var - Vaginata  6693 non-null   int64
#  2    Amanita brunneitoxicaria         6693 non-null   int64
#  3    Amanita phalloides-              6693 non-null   int64
#  4    Amanita princeps Corner - Bas    6693 non-null   int64
#  5    Chlorophyllum molybdites         6693 non-null   int64
#  6    Lactarius glaucescens            6693 non-null   int64
#  7    Lentinus polychrous Berk         6693 non-null   int64
#  8    Lentinus squarrosulas Mont       6693 non-null   int64
#  9    Macrolepiota gracilenta          6693 non-null   int64
#  10   Mycoamaranthus cambodgensis      6693 non-null   int64
#  11   Pleurotus pulmonarius            6693 non-null   int64
# ...

# %%
images.sum(numeric_only=True)
# Out:
#  Amanita Vaginata Var - Vaginata      28
#  Amanita brunneitoxicaria            500
#  Amanita phalloides-                 654
#  Amanita princeps Corner - Bas       564
#  Chlorophyllum molybdites            679
#  Lactarius glaucescens               655
#  Lentinus polychrous Berk            356
#  Lentinus squarrosulas Mont          129
#  Macrolepiota gracilenta             555
#  Mycoamaranthus cambodgensis         659
#  Pleurotus pulmonarius               120
#  Schizophylllum commune             1099
#  Scleroderma sinnamariense           695
# dtype: int64
